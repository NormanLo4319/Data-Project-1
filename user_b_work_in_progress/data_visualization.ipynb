# %% [markdown]
# ## Create Data Visualization for the Group Project

# %%
import pandas as pd
import pyhelpers as helper

# %%
# import data for cleaning
data = pd.read_csv('../data/crime.csv')
data = data.loc[~data['DR_NO'].isnull()]
# Out:
# C:\Users\Norman\AppData\Local\Temp\ipykernel_31428\114713649.py:2: DtypeWarning: Columns (1,2,5,9,10,12,13,15,17,18,19,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../data/crime.csv')

# %%
cleaned_df = helper.clean(df=data, missing=True, outliers=True, new_col=False)
cleaned_df
# Out:
#            crimeID       reportDate       eventDate  eventTime     areaName  \
# 0      190326475.0    3/1/2020 0:00   3/1/2020 0:00     2130.0     Wilshire
# 1      200106753.0    2/9/2020 0:00   2/8/2020 0:00     1800.0      Central
# 2      200320258.0  11/11/2020 0:00  11/4/2020 0:00     1700.0    Southwest
# 3      200907217.0   5/10/2023 0:00  3/10/2020 0:00     2037.0     Van Nuys
# 4      220614831.0   8/18/2022 0:00  8/17/2020 0:00     1200.0    Hollywood
# ...            ...              ...             ...        ...          ...
# 50461  201913134.0   8/11/2020 0:00  8/10/2020 0:00     2130.0      Mission
# 50462  200800857.0   11/9/2020 0:00  10/1/2020 0:00      600.0      West LA
# 50463  200514836.0   10/3/2020 0:00  10/2/2020 0:00      530.0       Harbor
# 50464  200405603.0   2/11/2020 0:00  2/11/2020 0:00     1230.0   Hollenbeck
# 50465  201505003.0   1/21/2020 0:00   1/8/2020 0:00     1200.0  N Hollywood
#
# ...
